# %% [markdown]
# ## 1. Views about the problem statement?
#
# The problem statement is essentially to Perform exploratory data analysis (EDA) on "Python-Corona", dataset to examining data distributions, identifying missing values, handling outliers, visualizing relationships between variables, and deriving meaningful insights from the data.
#
# The dataset includes the following columns: UserName, ScreenName, Location, TweetAt, OriginalTweet, and Sentiment. The target column "Sentiment" is a categorical column, have type as "Positive", "Positive", "Neutral", "Extremely Positive", and "Extremely Negative".

# %% [markdown]
# ## 2. Approach to solve this task?
# **2.1. Data Understanding and Tidying:-** First, to understand the given dataframe "Python-Corona" which contain Corona datas of tweeter customers.
#
# **2.2. Data Cleaning and Preprocessing:-** Perform the EDD (Extended Data Dictionary) process to check for missing values and Explore relationships between features and the target variable. As target variable is categorical so best preferal plot to cehck for outliers is box-plot and count-plots to identify the number for categories.
#
# **2.3. Exploratory Data Analysis (EDA):-** EDD treatment for missing values and outliers, if required and also to create dummies values for categorical variables.

# %% [markdown]
# ### 2.1. Data Understanding and Tidying
# ##### 2.1.1 Importing Numpy, Pandas, Seaborn, and matplot libraries for data intrepretation and visualization

# %%
import numpy as np     # Importing Numpy library 
import pandas as pd    # Importing Pandas library 
import seaborn as sns  # Importing Seaborn library 
import matplotlib.pyplot as plt  # Importing Matplot library

# %% [markdown]
# ##### 2.1.2 Loading and printing Python-Corona dataframe using pandas library
# **&rightarrow; Note:-Change the path location for all the three files**

# %%
# Loading and printing cities dataset excel file
Corona_data = pd.read_csv('E:/PHD ADMISSION/Om Namah Shivay/Job/Coorporate/Requin Solutions/Python-Corona.csv', header=0)
print(("\033[1m Corona_data \033[0m"), "\n", Corona_data, "\n")
# Out:
#  Corona_data
#         UserName  ScreenName                      Location     TweetAt  \
# 0          3799       48751                        London  16-03-2020
# 1          3800       48752                            UK  16-03-2020
# 2          3801       48753                     Vagabonds  16-03-2020
# 3          3802       48754                           NaN  16-03-2020
# 4          3803       48755                           NaN  16-03-2020
# ...         ...         ...                           ...         ...
# 41151     44951       89903  Wellington City, New Zealand  14-04-2020
# 41152     44952       89904                           NaN  14-04-2020
# 41153     44953       89905                           NaN  14-04-2020
# 41154     44954       89906                           NaN  14-04-2020
# 41155     44955       89907  i love you so much || he/him  14-04-2020
#
#                                            OriginalTweet           Sentiment
# ...

# %% [markdown]
# ### 2.2. Data Cleaning and Preprocessing
# ##### 2.2.1 EDD (Extended Data Dictionary) process to check for missing values

# %%
# To get the information about the "Corona_data" dataframe, including data types, non-null counts, and memory usage
Corona_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41156 entries, 0 to 41155
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41156 non-null  int64
#  1   ScreenName     41156 non-null  int64
#  2   Location       32566 non-null  object
#  3   TweetAt        41156 non-null  object
#  4   OriginalTweet  41156 non-null  object
#  5   Sentiment      41156 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %%
# To get the descriptive statistics of the "Corona_data" numeric columns
Corona_data.describe()
# Out:
#            UserName    ScreenName
# count  41156.000000  41156.000000
# mean   24377.490961  69329.490961
# std    11880.873691  11880.873691
# min     3799.000000  48751.000000
# 25%    14088.750000  59040.750000
# 50%    24377.500000  69329.500000
# 75%    34666.250000  79618.250000
# max    44955.000000  89907.000000

# %% [markdown]
# ##### 2.2.2  By using box-plot we can able to check for outliers for continous variables

# %%
# To visualize the distribution of 'UserName' in the "Corona_data" dataset and also to check for the outliers
sns.boxplot(y='UserName', data=Corona_data)
plt.title('Box Plot for UserName')
plt.show()

# %%
# To visualize the distribution of 'ScreenName' in the "Corona_data" dataset and also to check for the outliers
sns.boxplot(y='ScreenName', data=Corona_data)
plt.title('Box Plot for ScreenName')
plt.show()

# %% [markdown]
# ##### 2.2.3 Count-plot to analyse the total counts of categorical varaibles in  "Corona_data" dataframe

# %%
# To check the counts of observations in each categorical "Sentiment" bins using bar graph
sns.countplot(x='Sentiment', data = Corona_data)
# Out:
# <Axes: xlabel='Sentiment', ylabel='count'>

# %% [markdown]
# ##### 2.2.4  Checking for skewnwss for "UserName" and "ScreenName" column in  "Corona_data" dataframe

# %%
from scipy.stats import skew  # Import skewness model from scipy states model

# Create a histogram for 'UserName'
sns.histplot(data=Corona_data['UserName'])

# Calculate and print skewness for 'UserName'
skewness = skew(Corona_data['UserName'])
print("Skewness:", skewness)
# Out:
# Skewness: -4.4420382830614294e-06
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Create a histogram for 'ScreenName'
sns.histplot(data=Corona_data['ScreenName'])

# Calculate and print skewness for 'ScreenName'
skewness = skew(Corona_data['ScreenName'])
print("Skewness:", skewness)
# Out:
# Skewness: -4.4420382839995896e-06
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ##### 2.2.5  Check for the numbers of unique value for "UserName" and "ScreenName" columns in "Corona_data" dataframe

# %%
# Assuming 'Corona_data' in the DataFrame 'Corona_data' ii the column "UserName"
unique_UserName = Corona_data['UserName'].nunique()

print(f'The number of unique UserName is: {unique_UserName}')
# Out:
# The number of unique UserName is: 41156

# %%
# Assuming 'Corona_data' in the DataFrame 'Corona_data' ii the column "ScreenName"
unique_ScreenName = Corona_data['ScreenName'].nunique()

print(f'The number of unique ScreenName is: {unique_ScreenName}')
# Out:
# The number of unique ScreenName is: 41156

# %% [markdown]
# ### Observations after EDD on provided dataset
# ##### For the missing value obsevation for different columns
# &rightarrow; There are Missing values in "Location" column only of Corona_data dataset.
#
# &rightarrow; "Location" column have string data type so, for missing value treatment I, replaced all the null value with "NA".
#
# &rightarrow; "UserName" and "ScreenName" columns contain unique value and the total number of unique values are 41156.
#
# ##### For the outliers in varaiable, box-plots gives proper visualizatuions
# &rightarrow; There are no outliers showing in "UserName" and "ScreenName" columns
#
# **Note1-"UserName" and "ScreenName" contain unique values for all the customer, so checking for the outliers doesnt give any significance**
#
# **Note2-No outlier treatment are required for any columns**
#
# ##### For the count of categorical datas, count-plots gives proper visualizatuions
# &rightarrow; There are fice category in 'Sentiment' column and 'Sentiment' with positive category is more in compare to others.

# %% [markdown]
# ### 2.3. Exploratory Data Analysis (EDA)
# ##### 2.3.1 Missing value treatement "Location" column.

# %%
# Missing value treatment with the mean of the "Location" column in "Corona_data" dataframe
Corona_data.Location = Corona_data.Location.fillna("NA")

# %%
# After missing values treatment, get the information about the "Corona_data" dataframe, including data types, non-null counts
Corona_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41156 entries, 0 to 41155
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   UserName       41156 non-null  int64
#  1   ScreenName     41156 non-null  int64
#  2   Location       41156 non-null  object
#  3   TweetAt        41156 non-null  object
#  4   OriginalTweet  41156 non-null  object
#  5   Sentiment      41156 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 1.9+ MB

# %%
# define function for outlier treatment using box-plot concept
def treat_outliers(data, column):

    # Calculate Q1 (25th-percentile) and Q3 (75th-percentile)
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)

    # Calculate IQR
    IQR = Q3-Q1

    # Define the bounds for identifying outliers with standard threshold=1.5
    lower_bound = Q1-1.5*IQR
    upper_bound = Q3+1.5*IQR
    # print lower bound and upper bound
    print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")

    # Cap the outliers
    data[column] = data[column].apply(lambda x: lower_bound if x < lower_bound else (upper_bound if x > upper_bound else x))
    return data

# Treat outliers in "MaxTemp" column
sydney_rain = treat_outliers(sydney_rain, 'MaxTemp')

# Verify the outlier treatments for "MaxTemp" 
sns.boxplot(y='MaxTemp', data=sydney_rain)  
plt.title('Box Plot for MaxTemp After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 10.000000000000004, Upper Bound: 35.599999999999994

# %%
# Treat outliers in "Rainfall" column
sydney_rain = treat_outliers(sydney_rain, 'Rainfall')

# Verify the outlier treatments for "Rainfall"
sns.boxplot(y='Rainfall', data=sydney_rain)
plt.title('Box Plot for Rainfall After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: -2.0999999999999996, Upper Bound: 3.4999999999999996

# %%
# Treat outliers in "Evaporation" column
sydney_rain = treat_outliers(sydney_rain, 'Evaporation')

# Verify the outlier treatments for "Evaporation"
sns.boxplot(y='Rainfall', data=sydney_rain)
plt.title('Box Plot for Evaporation After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: -2.499999999999999, Upper Bound: 12.7

# %%
# Treat outliers in "Humidity9am" column
sydney_rain = treat_outliers(sydney_rain, 'Humidity9am')

# Verify the outlier treatments for "Humidity9am"
sns.boxplot(y='Humidity9am', data=sydney_rain)
plt.title('Box Plot for Humidity9am After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 25.0, Upper Bound: 113.0

# %%
# Treat outliers in "Humidity3pm" column
sydney_rain = treat_outliers(sydney_rain, 'Humidity3pm')

# Verify the outlier treatments for "Humidity3pm"
sns.boxplot(y='Humidity3pm', data=sydney_rain)
plt.title('Box Plot for Humidity3pm After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 14.0, Upper Bound: 94.0

# %%
# Treat outliers in "Pressure9am" column
sydney_rain = treat_outliers(sydney_rain, 'Pressure9am')

# Verify the outlier treatments for "Pressure9am"
sns.boxplot(y='Pressure9am', data=sydney_rain)
plt.title('Box Plot for Pressure9am After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 999.8499999999999, Upper Bound: 1037.0500000000002

# %%
# Treat outliers in "Pressure3pm" column
sydney_rain = treat_outliers(sydney_rain, 'Pressure3pm')

# Verify the outlier treatments for "Pressure3pm"
sns.boxplot(y='Pressure3pm', data=sydney_rain)
plt.title('Box Plot for Pressure3pm After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 997.05, Upper Bound: 1035.05

# %%
# Treat outliers in "Temp9am" column
sydney_rain = treat_outliers(sydney_rain, 'Temp9am')

# Verify the outlier treatments for "Temp9am"
sns.boxplot(y='Temp9am', data=sydney_rain)
plt.title('Box Plot for Temp9am After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 1.9500000000000028, Upper Bound: 33.55

# %%
# Treat outliers in "Temp3pm" column
sydney_rain = treat_outliers(sydney_rain, 'Temp3pm')

# Verify the outlier treatments for "Temp3pm"
sns.boxplot(y='Temp3pm', data=sydney_rain)
plt.title('Box Plot for Temp3pm After Outlier Treatment')
plt.show()
# Out:
# Lower Bound: 9.249999999999996, Upper Bound: 33.650000000000006

# %% [markdown]
# ##### 2.3.2 For data preprocessing, I removed the "Location", and "OriginalTweet" columns that contain the string type data

# %%
del Corona_data["Location"]

# %%
del Corona_data["OriginalTweet"]

# %%
del Corona_data["TweetAt"]

# %% [markdown]
# ##### 2.3.3 Creating dummies values for categorical variables

# %%
# converts the categorical variables in the DataFrame "Corona_data" into dummy variables and convert it into float data type
Corona_data = pd.get_dummies(Corona_data, columns=["Sentiment"], drop_first=True).astype(float)

# %%
# To get the information about the "Corona_data" dataframe, including data types, non-null counts, 
# and memory usage after creating dummies value
Corona_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41156 entries, 0 to 41155
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   UserName                      41156 non-null  float64
#  1   ScreenName                    41156 non-null  float64
#  2   Sentiment_Extremely Positive  41156 non-null  float64
#  3   Sentiment_Negative            41156 non-null  float64
#  4   Sentiment_Neutral             41156 non-null  float64
#  5   Sentiment_Positive            41156 non-null  float64
# dtypes: float64(6)
# memory usage: 1.9 MB

# %%
# To display the first few rows of  "sydney_rain" dataframe to check for the created dummies variables
Corona_data.head()
# Out:
#    UserName  ScreenName  Sentiment_Extremely Positive  Sentiment_Negative  \
# 0    3799.0     48751.0                           0.0                 0.0
# 1    3800.0     48752.0                           0.0                 0.0
# 2    3801.0     48753.0                           0.0                 0.0
# 3    3802.0     48754.0                           0.0                 0.0
# 4    3803.0     48755.0                           0.0                 0.0
#
#    Sentiment_Neutral  Sentiment_Positive
# 0                1.0                 0.0
# 1                0.0                 1.0
# 2                0.0                 1.0
# 3                0.0                 1.0
# 4                0.0                 0.0

# %%
Corona_data.corr()
# Out:
#                               UserName  ScreenName  \
# UserName                      1.000000    1.000000
# ScreenName                    1.000000    1.000000
# Sentiment_Extremely Positive  0.024551    0.024551
# Sentiment_Negative           -0.022215   -0.022215
# Sentiment_Neutral             0.025093    0.025093
# Sentiment_Positive            0.014101    0.014101
#
#                               Sentiment_Extremely Positive  \
# UserName                                          0.024551
# ScreenName                                        0.024551
# Sentiment_Extremely Positive                      1.000000
# Sentiment_Negative                               -0.246753
# Sentiment_Neutral                                -0.210333
# Sentiment_Positive                               -0.271452
#
#                               Sentiment_Negative  Sentiment_Neutral  \
# UserName                               -0.022215           0.025093
# ...

# %%
Corona_data.describe()
# Out:
#            UserName    ScreenName  Sentiment_Extremely Positive  \
# count  41156.000000  41156.000000                  41156.000000
# mean   24377.490961  69329.490961                      0.160949
# std    11880.873691  11880.873691                      0.367488
# min     3799.000000  48751.000000                      0.000000
# 25%    14088.750000  59040.750000                      0.000000
# 50%    24377.500000  69329.500000                      0.000000
# 75%    34666.250000  79618.250000                      0.000000
# max    44955.000000  89907.000000                      1.000000
#
#        Sentiment_Negative  Sentiment_Neutral  Sentiment_Positive
# count        41156.000000       41156.000000        41156.000000
# mean             0.240937           0.187409            0.277529
# std              0.427657           0.390244            0.447785
# min              0.000000           0.000000            0.000000
# ...
